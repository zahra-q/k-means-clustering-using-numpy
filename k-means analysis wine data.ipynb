# %% [markdown]
# Implementation and performance of k-mean clustering analysis Using Numpy & Python
# - Group Number :- 15
#
# Group Member Names :-
#
# - Vinamrata Sankhe
#
# - Zahra Qureshi
#
# - Shriya Raj Mahan
#
# - Hemanth Rao
#
# With the uploaded dataset, implement and perform k-mean clustering analysis
# - Using Python numpy library
# - Other libraries, e.g. scikit-learn, are not allowed for calculations

# %% [markdown]
# # Abstract

# %% [markdown]
# The k-means problem is solved using either Lloyd’s or Elkan’s algorithm.
#
# The average complexity is given by O(k n T), where n is the number of samples and T is the number of iteration.
#
# The worst case complexity is given by O(n^(k+2/p)) with n = n_samples, p = n_features.
#
# In practice, the k-means algorithm is very fast (one of the fastest clustering algorithms available), but it falls in local minima. That’s why it can be useful to restart it several times.
#
# If the algorithm stops before fully converging (because of tol or max_iter), labels_ and cluster_centers_ will not be consistent, i.e. the cluster_centers_ will not be the means of the points in each cluster. Also, the estimator will reassign labels_ after the last iteration to make labels_ consistent with predict on the training set.
#
# In our project we will be implementing the K-mean clustering analysis. With the data the input values were used to test our code and train the network on the training data.

# %% [markdown]
# # Theory

# %% [markdown]
# The k-means clustering method is an unsupervised machine learning technique used to identify clusters of data objects in a dataset. There are many different types of clustering methods, but k-means is one of the oldest and most approachable. These traits make implementing k-means clustering in Python reasonably straightforward, even for novice programmers and data scientists. In this project we do the k-mean analysis by first importing the pandas and numpy libraries.
#
# After importing the nessacary libraries we import the data file by using the read_csv() function after reading the file We use head() function to get the first n rows.  We use it for quickly testing if your object has the right type of data in it. Then We use head() function to get the first n rows and also for quickly testing if your object has the right type of data in it. If we get the result for all the headings as null then there are no missing values in the data then we can proceed for the plots and if there are any missing values the we find them using the mean or diffrent techniques.
#
# After conforming there are no missing values the we use the plt.figure function to boxplot the data.The purpose of using plt. figure() is to create a figure object. The whole figure is regarded as the figure object. The figsize attribute allows us to specify the width and height of a figure in unit inches by default the figure has the dimensions as (6.4, 4.8) but we have used 23,8.
#
# In the exploratary data analysis we import the seaborn library it is used for making statistical graphics in Python. Seaborn helps you explore and understand your data. Its plotting functions operate on dataframes and arrays containing whole datasets and internally perform the necessary semantic mapping and statistical aggregation to produce informative plots. Then we use sns.distplot on Alchol data to find the variation in the data distribution and also to find the overall distribution of continuous data variables. Then we use the sns.scatterplot to find the relation between the alcohol and Alcalinity of ash that shows the relationship between different variables in this two datasets. This data is shown by placing various data points between an x- and y-axis. We are showing relationship between the Alcohol as (x) and Alcalinity of ash as (y). After that we use sns.distplot on Hue to find univariate distribution of observations on the data of Hue.
#
# We use sns.scatterplot on data of Magnesium and data of OD280/OD315 of diluted wines and also for the data of Proanthocyanins and data of Ash to find the relationship between different variables in this two datasets. Then use the scatter() function on the data of Total phenols and data of Flavanoids to represent relation among variables and how change in one affects the other.
#
# In the model building After using the scatterplot we import the numpy and cdist to calculate the distance between the centroids. To find the the distance we choose the centroids randomly and find the distance between all the data points and caluculating the centroids with minimum distance. To decrease the error we repeat the iterations with a defined number and with the mean of clusters we will update the centroids then we use Principal component analysis (PCA) to input data is centered but not scaled for each feature before applying the SVD.

# %% [markdown]
# # Analysis Results and Explanation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("DSCI6001_prj2_data.csv")

# %% [markdown]
# We use the Pandas read_csv() function to import the CSV file-DSCI6001_prj2_data.csv

# %%
data.head()
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0    14.23        1.71  2.43               15.6        127           2.80
# 1    13.20        1.78  2.14               11.2        100           2.65
# 2    13.16        2.36  2.67               18.6        101           2.80
# 3    14.37        1.95  2.50               16.8        113           3.85
# 4    13.24        2.59  2.87               21.0        118           2.80
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280/OD315 of diluted wines  Proline
# ...

# %% [markdown]
# We use head() function to get the first n rows. This function returns the first n rows for the object based on position. We use it for quickly testing if your object has the right type of data in it.

# %%
data.isnull().sum()
# Out:
# Alcohol                         0
# Malic acid                      0
# Ash                             0
# Alcalinity of ash               0
# Magnesium                       0
# Total phenols                   0
# Flavanoids                      0
# Nonflavanoid phenols            0
# Proanthocyanins                 0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# dtype: int64

# %% [markdown]
# We use data.isnull().sum() to know how many missing values in the data

# %%
plt.figure(figsize=(23, 8))
data.boxplot(grid = False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The purpose of using plt. figure() is to create a figure object. The whole figure is regarded as the figure object.The figsize attribute allows us to specify the width and height of a figure in unit inches. The figsize attribute is a parameter of the function figure(). It is an optional attribute, by default the figure has the dimensions as (6.4, 4.8) but we have used 23,8.

# %% [markdown]
# ### Exploratory Data Analysis

# %%
import seaborn  as sns

# %% [markdown]
# Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures.
#
# Seaborn helps you explore and understand your data. Its plotting functions operate on dataframes and arrays containing whole datasets and internally perform the necessary semantic mapping and statistical aggregation to produce informative plots. Its dataset-oriented, declarative API lets you focus on what the different elements of your plots mean, rather than on the details of how to draw them.

# %%
sns.distplot(data["Alcohol"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Alcohol', ylabel='Density'>

# %% [markdown]
# A Distplot or distribution plot, depicts the variation in the data distribution. Seaborn Distplot represents the overall distribution of continuous data variables. ... The Distplot depicts the data by a histogram and a line in combination to it. We are using it for the data in Alcohol.

# %%
sns.scatterplot(data["Alcohol"],data["Alcalinity of ash"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Alcohol', ylabel='Alcalinity of ash'>

# %% [markdown]
# A scatter plot is a type of data visualization that shows the relationship between different variables. This data is shown by placing various data points between an x- and y-axis. We are showing relationship between the Alcohol as (x) and Alcalinity of ash as (y).

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(data["Total phenols"])
plt.show()

# %% [markdown]
# The hist() function in pyplot module of matplotlib library is used to plot a histogram. This parameter is an optional parameter and it is used to draw type of histogram.

# %%
sns.distplot(data["Hue"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Hue', ylabel='Density'>

# %% [markdown]
# Seaborn distplot lets you show a histogram with a line on it. This can be shown in all kinds of variations. We use seaborn in combination with matplotlib, the Python plotting module. A distplot plots a univariate distribution of observations.

# %%
sns.scatterplot(data["Magnesium"],data["OD280/OD315 of diluted wines"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Magnesium', ylabel='OD280/OD315 of diluted wines'>

# %% [markdown]
# A scatter plot is a type of data visualization that shows the relationship between different variables. This data is shown by placing various data points between an x- and y-axis. We are showing relationship between the Magnesium as (x) and OD280/OD315 of diluted wines as (y).

# %%
sns.scatterplot(data["Proanthocyanins"],data["Ash"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Proanthocyanins', ylabel='Ash'>

# %% [markdown]
# A scatter plot is a type of data visualization that shows the relationship between different variables. This data is shown by placing various data points between an x- and y-axis. We are showing relationship between the Proanthocyanins as (x) and Ash as (y).

# %%
plt.scatter(data["Total phenols"],data["Flavanoids"])

# %% [markdown]
# The scatter() method in the matplotlib library is used to draw a scatter plot. Scatter plots are widely used to represent relation among variables and how change in one affects the other.

# %%
sns.distplot(data["Magnesium"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Magnesium', ylabel='Density'>

# %% [markdown]
# Seaborn distplot lets you show a histogram with a line on it. This can be shown in all kinds of variations. We use seaborn in combination with matplotlib, the Python plotting module. A distplot plots a univariate distribution of observations. We are using the sns.distplot for Magnesium data.

# %%
sns.scatterplot(data["Hue"],data["Proanthocyanins"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Hue', ylabel='Proanthocyanins'>

# %% [markdown]
# A scatter plot is a type of data visualization that shows the relationship between different variables. This data is shown by placing various data points between an x- and y-axis. We are showing relationship between the Hue as (x) and Proanthocyanins as (y).

# %% [markdown]
# ### Building A Model

# %%
import numpy as np
from scipy.spatial.distance import cdist 
def kmeans(x,k, no_of_iterations):
    idx = np.random.choice(len(x), k, replace=False)
    #Randomly choosing Centroids 
    centroids = x[idx, :] #Step 1
     
    #finding the distance between centroids and all the data points
    distances = cdist(x, centroids ,'euclidean') #Step 2
     
    #Centroid with the minimum Distance
    points = np.array([np.argmin(i) for i in distances]) #Step 3
     
    #Repeating the above steps for a defined number of iterations
    #Step 4
    for _ in range(no_of_iterations): 
        centroids = []
        for idx in range(k):
            #Updating Centroids by taking mean of Cluster it belongs to
            temp_cent = x[points==idx].mean(axis=0) 
            centroids.append(temp_cent)
 
        centroids = np.vstack(centroids) #Updated Centroids 
         
        distances = cdist(x, centroids ,'euclidean')
        points = np.array([np.argmin(i) for i in distances])
         
    return points

# %% [markdown]
# After importing the numpy we import the cdist to calculate the distance between the centroids. To find the the distance we choose the centroids randomly and find the distance between all the data points and caluculating the centroids with minimum distance. To decrease the error we repeat the iterations with a defined number and with the mean of clusters we will update the centroids.

# %%
from sklearn.decomposition import PCA
pca = PCA(2)
df = pca.fit_transform(data)
 
#Applying our function
label = kmeans(df,3,1000)
 
#Visualize the results
 
u_labels = np.unique(label)
for i in u_labels:
    plt.scatter(df[label == i , 0] , df[label == i , 1] , label = i)
plt.legend()
plt.show()

# %% [markdown]
# Principal component analysis (PCA). Linear dimensionality reduction using Singular Value Decomposition of the data to project it to a lower dimensional space. The input data is centered but not scaled for each feature before applying the SVD.

# %% [markdown]
# # Conclusion

# %% [markdown]
# - By using k=3, we clustered the data into three groups on the basis of the Malic Acid and Hue features.
# - We ran 1000 iterations of the algorithm since insufficient iterations would lead to poor results. With a large number of iterations, we ensure that our algorithm converges where our centroids do not change, and we get the best clusters.
